# %%
import pandas as pd
df = pd.read_csv('data/country_data.csv', sep=',', skiprows=0, header=0)
display(df.shape)
# Out:
# (142, 5)

# %%
print(df['continent'].value_counts())
# Out:
# Africa      52
# Asia        33
# Europe      30
# Americas    25
# Oceania      2
# Name: continent, dtype: int64

# %%
p = df.loc[:,'country':'pop']

# %%
print(df.iloc[:,3:4].max())
# Out:
# lifeExp    82.603
# dtype: float64

# %%
print(df.iloc[:,4:5].median())
# Out:
# gdpPercap    6124.371109
# dtype: float64

# %%
print(df['pop'].sum())
# Out:
# 6251013179.0

# %%
import matplotlib.pyplot as plt
plt.hist(df['lifeExp'], bins=15)
plt.xlabel('Life expectancy [years]')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(df['lifeExp'])
plt.ylabel('Life expectancy [years]')
plt.show()
